# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os

complaints_path_dir =  '/content/drive/MyDrive/Жалобы жкх'
files_names = []

for file_name in os.listdir(complaints_path_dir):
    file_df = pd.read_csv(os.path.join(complaints_path_dir, file_name))
    files_names += [file_df]

files_names
# Out:
# [    id                                              текст         категория  \
#  0    1  В подъезде третий день мигает лампочка, глаза ...         электрика
#  1    2  Из крана течёт ржавая вода, чайник после этого...              вода
#  2    3  Ну и где наше отопление? На улице +5, а батаре...         отопление
#  3    4  Лифт как обычно встал. Вчера — сегодня — навер...              лифт
#  4    5  Опять мусор не вывезли! Коты устроили фестивал...             мусор
#  5    6  Канализацией воняет на весь двор, особенно веч...       канализация
#  6    7  Дети не могут играть — горка вся ржавая и шата...  детская_площадка
#  7    8  В подвале кто-то живёт, ночью слышно кашель и ...            подвал
#  8    9  Соседи сверху снова заливают, уже четвёртый ра...        затопление
#  9   10  В лифте нет света, но зато теперь можно устраи...              лифт
#  10  11  Фонари во дворе не работают, хоть фонарик с со...         освещение
# ...

# %%
df = pd.concat(files_names, ignore_index=True)

df.head()
# Out:
#    id                                              текст  категория срочность  \
# 0   1  В подъезде третий день мигает лампочка, глаза ...  электрика   средняя
# 1   2  Из крана течёт ржавая вода, чайник после этого...       вода   высокая
# 2   3  Ну и где наше отопление? На улице +5, а батаре...  отопление   высокая
# 3   4  Лифт как обычно встал. Вчера — сегодня — навер...       лифт   средняя
# 4   5  Опять мусор не вывезли! Коты устроили фестивал...      мусор   высокая
#
#         эмоция                   сущности
# 0  раздражение   подъезд, лампочка, 3 дня
# 1   отвращение       вода, кран, ржавчина
# 2         гнев  отопление, температура:+5
# 3  раздражение                       лифт
# 4   отвращение          мусор, контейнеры

# %%
df['id'] = range(1, len(df)+1)

# %%
df.head()
# Out:
#    id                                              текст  категория срочность  \
# 0   1  В подъезде третий день мигает лампочка, глаза ...  электрика   средняя
# 1   2  Из крана течёт ржавая вода, чайник после этого...       вода   высокая
# 2   3  Ну и где наше отопление? На улице +5, а батаре...  отопление   высокая
# 3   4  Лифт как обычно встал. Вчера — сегодня — навер...       лифт   средняя
# 4   5  Опять мусор не вывезли! Коты устроили фестивал...      мусор   высокая
#
#         эмоция                   сущности
# 0  раздражение   подъезд, лампочка, 3 дня
# 1   отвращение       вода, кран, ржавчина
# 2         гнев  отопление, температура:+5
# 3  раздражение                       лифт
# 4   отвращение          мусор, контейнеры

# %% [markdown]
# Дубликатов нет

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('/content/drive/MyDrive/Жалобы жкх/jkh_dataset.csv', index=False)
